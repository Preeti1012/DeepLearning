# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.preprocessing import sequence
from keras import backend as K
from keras.preprocessing.text import Tokenizer
from keras.layers.core import Dense, Dropout, Activation
from keras.layers import Dense, Dropout, Reshape, Flatten, concatenate, Input, Conv1D, Embedding
from keras.layers.convolutional import Convolution1D, MaxPooling1D
from keras.layers.embeddings import Embedding
from keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# # Combining twitter dataset

# %%
df1 = pd.read_csv('awesome.csv')
df1.tail()
# Out:
#                                                    text  id
# 4995  @AnnieYuTV Where did you get it? It’s looks aw...   4
# 4996          @IdreesCrawley Any ideas would be awesome   4
# 4997                       @dhancock110 Dude is awesome   4
# 4998  @theretrobyte Dpaint, which came with my Amiga...   4
# 4999  Get my art printed on awesome products. Suppor...   4

# %%
df2 = pd.read_csv('bravo.csv')
df2.tail()
# Out:
#                                                    text  id
# 1495  @PhillMReich BRAVO. I knew that you would deli...   5
# 1496  Remember Indian movie actor Harithik Roshan, H...   5
# 1497  #OnThisDay in 1980 : 40 years ago today, the f...   5
# 1498  @Archangel_Dean2 *get her attention but bravo....   5
# 1499  @MizaDaDawn @suprise_Dr @TakaTina1 #Delta101Ga...   5

# %%
df3 = pd.read_csv('depress.csv')
df3.tail()
# Out:
#                                                   text  id
# 995  @MarqRobinson Is it bad if I, as a man, realiz...  10
# 996  Don’t nobody love you when you doin bad... the...  10
# 997  @fmanjoo @the_unachiever Ok, so we're supposed...  10
# 998  ice cream by blackpink and selena gomez isn't ...  10
# 999  @BgWith I rlly need halo fragment can so bad I...  10

# %%
df4 = pd.read_csv('fear.csv')
df4.tail()
# Out:
#                                                    text  id
# 4995  @FrankLuntz @jonathanvswan I’m sick to my stom...  11
# 4996  @JohnFromCranber @stillgray @PrisonPlanet Is t...  11
# 4997  🕊Monday Verse of the Day🕊\r\n\r\nDo not be wis...  11
# 4998  @SvenKolbow @realpedroleo @SeibtNaomi How can ...  11
# 4999  when the Government say that xxxx tested posit...  11

# %%
df5 = pd.read_csv('glad.csv')
df5.tail()
# Out:
#                                                    text  id
# 4995  @VeronicaSam13 I'm glad I'm not like that. I d...   2
# 4996  @500milesforGRiT @marinamaral2 I’m so glad - t...   2
# 4997  I'm so glad Jacob attorneys was there 2 let Am...   2
# 4998             Slow half. Glad footballs back though!   2
# 4999  I’m watching the bill and ted movie. I’m glad ...   2

# %%
df6 = pd.read_csv('happy.csv')
df6.tail()
# Out:
#                                                    text  id
# 4995                     @hadd_ho_gaye Happy birthday 🎂   1
# 4996         So happy for you!! https://t.co/nMqtjUSHX4   1
# 4997  @EternalHokageYT Thanks for everything bro! We...   1
# 4998  @drTempleGrandin Happy Birthday! We hope you h...   1
# 4999                         @PlayStacin Happy birthday   1

# %%
df7 = pd.read_csv('horror.csv')
df7.tail()
# Out:
#                                                    text  id
# 4995  @DragonBeck Have you never watched a horror fi...  14
# 4996  @wildmanjohn10 @AndFreedoms He’s given up on i...  14
# 4997  Vampires, mythological action/adventure, stran...  14
# 4998  Avon, 1969. “They new that something foul and ...  14
# 4999  @maljutley Mine are:\r\n\r\n12 Hour Shift\r\nD...  14

# %%
df8 = pd.read_csv('insult.csv')
df8.tail()
# Out:
#                                                    text  id
# 4995  @HinduJagrutiOrg @goelgauravbjp Everyone comes...   7
# 4996  @Bharath59874953 @RaviCha11766249 @Hackey_007 ...   7
# 4997  both\r\na compliment to your intelligence \r\n...   7
# 4998  @HAHayatu @Balatic Now I understand you better...   7
# 4999  if woke/antifa is an insult, what are you? a f...   7

# %%
df9 = pd.read_csv('panic.csv')
df9.tail()
# Out:
#                                                    text  id
# 4995  Steve Irwin: *gets bit on the neck by a python...  13
# 4996  @pinkettescash Her embarrassment is starting t...  13
# 4997  So... People are cancelling the McElroys for.....  13
# 4998                               Panic attack loading  13
# 4999  eh.. remember those chinese who were walking d...  13

# %%
df10 = pd.read_csv('sad.csv')
df10.tail()
# Out:
#                                                    text  id
# 4995  It’s just so sad that after all she put into i...   6
# 4996  i used to be sad as hell i win the sweepstakes...   6
# 4997    this edit I’m so sad 🥺😔 https://t.co/yUvb3GRCoY   6
# 4998                             @sunosutoara big sad😔😔   6
# 4999  Am very sad that no one told me there were pho...   6

# %%
df11 = pd.read_csv('sorrow.csv')
df11.tail()
# Out:
#                                                    text  id
# 4995  the best way for me to express my pain and sor...   8
# 4996  Fuck livin', I'ma drown in my sorrow Fuck givi...   8
# 4997  This year has been the worst year of my life. ...   8
# 4998  "What kind of person sues nuns? I can't stand ...   8
# 4999  May Allah keep you safe, well and always happy...   8

# %%
df12 = pd.read_csv('terror.csv')
df12.tail()
# Out:
#                                                   text  id
# 995               @The3rdCurly THE TERROR OF SANTA FE.  12
# 996  strongly agree !\r\ndisappearing is a terror a...  12
# 997  @BluegrassPundit @LEX18News The FBI has stated...  12
# 998  @Diplomat_APAC Red lines, white terror and sel...  12
# 999  Hotel Rwanda hero arrested on terror charges -...  12

# %%
df13 = pd.read_csv('upset.csv')
df13.tail()
# Out:
#                                                    text  id
# 4995  he is upset because they wont include him http...   9
# 4996  @Sonofamafia Don't forget to add de Olu Samini...   9
# 4997  @heydianaheyy switching to this acc bc this is...   9
# 4998  @OncOfThousands "I don't. . . I don't have any...   9
# 4999  @The_RubyRose Someone is actually upset that C...   9

# %%
df14 = pd.read_csv('worry.csv')
df14.tail()
# Out:
#                                                    text  id
# 4995  @aliangehhh don’t worry math is easy. you’re g...  15
# 4996  @z_v0rTeX_z @skinniyoojung don’t worry man ur ...  15
# 4997  ..stuck with assignments? worry no more, our t...  15
# 4998  @renjunspabo denise, dont worry about it. take...  15
# 4999  @laxmina92497023 @OfficeOfDGP And then Ladakh ...  15

# %%
df15 = pd.read_csv('wow.csv')
df15.tail()
# Out:
#                                                    text  id
# 4995  @JacobWa1890 @NSB_Bot @cookalerts @BlankProxie...   3
# 4996       @bubfromtheflats Wow lmfao look how foolish🥴   3
# 4997  wow..instead of effects theyre called prayers....   3
# 4998  @sworrall @CarryStrategy Wow -- I'd heard of i...   3
# 4999  @BloodRaven55 WOW THE TIMING ON THIS IS INCREIBLE   3

# %%
dfh = pd.concat([df1,df2,df5,df6,df15], axis = 0, ignore_index = True)

# %%
dfs = pd.concat([df3,df8,df10,df11,df13], axis = 0, ignore_index = True)

# %%
dff = pd.concat([df4,df7,df9,df12,df14], axis = 0, ignore_index = True)

# %%
print(dfh.head())
print(dfs.head())
print(dff.head())
# Out:
#                                                 text  id
# 0  I want to play Ludo King with you! Please inst...   4
# 1  @changed_2020 👏👏 awesome haha. Long may it con...   4
# 2  @theseedpicker @LucyRacquelandM Awesome! 😍 Tha...   4
# 3  @Casey @nineteeneea Awesome how he touched peo...   4
# 4  How sweet! Alexxis Birthday message to @ItsJoD...   4
#                                                 text  id
# 0  Day 5 post opp, dressings still on, not sure i...  10
# 1  @itzzfranco It’s a fake video. If Trump would ...  10
# 2  @LightlessThrust T-That’s a bad thing...it mea...  10
# 3  @EricBoehlert "We are efforting outreach"??? 🤣...  10
# 4  @Swamy39 @IndiaToday Based media clips, it's m...  10
#                                                 text  id
# 0  good monday jamal murray van gogh big east lad...  11
# 1  @holmesianlove It just absolutely shatters my ...  11
# 2  @YousufLFC @gaucholemz Fear Allah, don’t lie l...  11
# ...

# %%
# df.to_csv('twitter_sentiment_dataset.csv')

# %%
dfh['pre_clean_len'] = [len(t) for t in dfh.text]
dfh.head()
# Out:
#                                                 text  id  pre_clean_len
# 0  I want to play Ludo King with you! Please inst...   4            119
# 1  @changed_2020 👏👏 awesome haha. Long may it con...   4             90
# 2  @theseedpicker @LucyRacquelandM Awesome! 😍 Tha...   4             72
# 3  @Casey @nineteeneea Awesome how he touched peo...   4            138
# 4  How sweet! Alexxis Birthday message to @ItsJoD...   4            117

# %%
dfs['pre_clean_len'] = [len(t) for t in dfs.text]
dfs.head()
# Out:
#                                                 text  id  pre_clean_len
# 0  Day 5 post opp, dressings still on, not sure i...  10             85
# 1  @itzzfranco It’s a fake video. If Trump would ...  10            140
# 2  @LightlessThrust T-That’s a bad thing...it mea...  10             73
# 3  @EricBoehlert "We are efforting outreach"??? 🤣...  10             97
# 4  @Swamy39 @IndiaToday Based media clips, it's m...  10            140

# %%
dff['pre_clean_len'] = [len(t) for t in dff.text]
dff.head()
# Out:
#                                                 text  id  pre_clean_len
# 0  good monday jamal murray van gogh big east lad...  11            140
# 1  @holmesianlove It just absolutely shatters my ...  11            139
# 2  @YousufLFC @gaucholemz Fear Allah, don’t lie l...  11             60
# 3  @CommiesLmao These perpetrators feel empowered...  11            140
# 4  time+is+come,+I+fear,+when+I+must+open+the+par...  11             59

# %% [markdown]
# # Data Cleaning

# %%
# import re
# # print(df.text[1])
# for i in range(10):
#     df.text[i] = re.sub(r'@[A-Za-z0-9]+','',df.text[i])
# df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                                                     text  id  pre_clean_len
# 0      I want to play Ludo King with you! Please inst...   4            119
# 1      _2020 👏👏 awesome haha. Long may it continue. W...   4             90
# 2               Awesome! 😍 Thank you! 🙏 Great list!! ✨🎧✨   4             72
# 3        Awesome how he touched people by not only hi...   4            138
# 4      How sweet! Alexxis Birthday message to  🥺 Happ...   4            117
# 5       Sorry to Bother You...and it was brilliant an...   4             74
# 6                                     You look awesome🐾❤   4             35
# ...

# %%
# for i in range(20):
#     df.text[i] = re.sub('https?://[A-Za-z0-9./]+','',df.text[i])
# df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                     text  id  pre_clean_len
# 0      I want to play Ludo King with you! Please inst...   4            119
# 1      _2020 👏👏 awesome haha. Long may it continue. W...   4             90
# 2               Awesome! 😍 Thank you! 🙏 Great list!! ✨🎧✨   4             72
# 3        Awesome how he touched people by not only hi...   4            138
# 4      How sweet! Alexxis Birthday message to  🥺 Happ...   4            117
# 5       Sorry to Bother You...and it was brilliant an...   4             74
# 6                                     You look awesome🐾❤   4             35
# 7      Just saw  in an awesome panel at the  #Festiva...   4            112
# ...

# %%
# for i in range(50):
#     df.text[i] = re.sub("[^a-zA-Z]", " ", df.text[i])
# df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                     text  id  pre_clean_len
# 0      I want to play Ludo King with you  Please inst...   4            119
# 1               awesome haha  Long may it continue  W...   4             90
# 2               Awesome    Thank you    Great list         4             72
# 3        Awesome how he touched people by not only hi...   4            138
# 4      How sweet  Alexxis Birthday message to    Happ...   4            117
# 5       Sorry to Bother You   and it was brilliant an...   4             74
# 6                                     You look awesome     4             35
# 7      Just saw  in an awesome panel at the   Festiva...   4            112
# ...

# %%
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))

def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    clean = re.sub(combined_pat, '', souped)
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()

# %%
# testing = df.text[:100]
# test_result = []
# for t in testing:
#     test_result.append(tweet_cleaner(t))
# test_result
# Out:
# ['i want to play ludo king with you please install from android ios',
#  'awesome haha long may it continue we are watching the new baywatch xx',
#  'awesome thank you great list',
#  'awesome how he touched people by not only his talents but by his character that related to the masses rip king',
#  'how sweet alexxis birthday message to happy birthday joel have an awesome day',
#  'sorry to bother you and it was brilliant and weird and awesome',
#  'you look awesome',
#  'just saw in an awesome panel at the festivalofbooks well done',
#  'wray s fbi is awesome',
#  'nolacak kanka d n p taga destek vermen de yeter you are awesome i will always be proud o',
#  'sno looks awesome what armor set is she wearing',
#  'this is such an awesome video what a wonderful neighbor i wish he was my neighbor in fact i will trade one of my',
#  'this is awesome dude',
#  'sissy i go to the jobsite and do work the jobsite pays m',
#  'brunch dates gt gt gt gt',
#  'awesome night',
# ...

# %%
dff.shape
# Out:
# (21000, 3)

# %%
nums = [0,10000,21500]
print("Cleaning and parsing the tweets...\n")
clean_tweet_texts_h = []
for i in range(nums[0],nums[2]):
    if( (i+1)%10000 == 0 ):
        print("Tweets %d of %d has been processed" %(i+1, nums[2]))                                                                    
    clean_tweet_texts_h.append(tweet_cleaner(dfh['text'][i]))
# Out:
# Cleaning and parsing the tweets...
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "https://t.co/UP84FttcD1
#
# Awesome" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Tweets 10000 of 21500 has been processed
# Tweets 20000 of 21500 has been processed

# %%
nums = [0,10000,21000]
print("Cleaning and parsing the tweets...\n")
clean_tweet_texts_s = []
for i in range(nums[0],nums[2]):
    if( (i+1)%10000 == 0 ):
        print("Tweets %d of %d has been processed" %(i+1, nums[2]))                                                                    
    clean_tweet_texts_s.append(tweet_cleaner(dfs['text'][i]))
# Out:
# Cleaning and parsing the tweets...
#
# Tweets 10000 of 21000 has been processed
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "https://t.co/XDl0Q1g4NQ
# Sorrow.😭" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Tweets 20000 of 21000 has been processed

# %%
nums = [0,10000,21000]
print("Cleaning and parsing the tweets...\n")
clean_tweet_texts_f = []
for i in range(nums[0],nums[2]):
    if( (i+1)%10000 == 0 ):
        print("Tweets %d of %d has been processed" %(i+1, nums[2]))                                                                    
    clean_tweet_texts_f.append(tweet_cleaner(dff['text'][i]))
# Out:
# Cleaning and parsing the tweets...
#
# Tweets 10000 of 21000 has been processed
# Tweets 20000 of 21000 has been processed

# %%
len(clean_tweet_texts_f)
# Out:
# 21000

# %%
clean_df_h = pd.DataFrame(clean_tweet_texts_h,columns=['text'])
clean_df_h['target'] = 0
print(clean_df_h.head())

clean_df_s = pd.DataFrame(clean_tweet_texts_s,columns=['text'])
clean_df_s['target'] = 1
print(clean_df_s.head())

clean_df_f = pd.DataFrame(clean_tweet_texts_f,columns=['text'])
clean_df_f['target'] = 2
print(clean_df_f.head())
# Out:
#                                                 text  target
# 0  i want to play ludo king with you please insta...       0
# 1  awesome haha long may it continue we are watch...       0
# 2                       awesome thank you great list       0
# 3  awesome how he touched people by not only his ...       0
# 4  how sweet alexxis birthday message to happy bi...       0
#                                                 text  target
# 0  day post opp dressings still on not sure if th...       1
# 1  it s a fake video if trump would address admit...       1
# 2  t that s a bad thing it means you re not even ...       1
# 3  we are efforting outreach right lol you all li...       1
# 4  based media clips it s most unlikely rhea chak...       1
#                                                 text  target
# 0  good monday jamal murray van gogh big east lad...       2
# 1  it just absolutely shatters my heart that bc c...       2
# ...

# %%
clean_df = pd.concat([clean_df_h,clean_df_s,clean_df_f], axis = 0, ignore_index = True)
clean_df.to_csv('clean_tweet.csv',encoding='utf-8')
# csv = 'clean_tweet.csv'
# my_df = pd.read_csv(csv,index_col=0)
# my_df.head()
# Out:
#                                                 text  target
# 0  i want to play ludo king with you please insta...       0
# 1  awesome haha long may it continue we are watch...       0
# 2                       awesome thank you great list       0
# 3  awesome how he touched people by not only his ...       0
# 4  how sweet alexxis birthday message to happy bi...       0

# %%
csv = 'clean_tweet.csv'
my_df = pd.read_csv(csv,index_col=0)
my_df.head()
# Out:
#                                                 text  target
# 0  i want to play ludo king with you please insta...       0
# 1  awesome haha long may it continue we are watch...       0
# 2                       awesome thank you great list       0
# 3  awesome how he touched people by not only his ...       0
# 4  how sweet alexxis birthday message to happy bi...       0

# %%
my_df[my_df.isnull().any(axis=1)]
# Out:
#       text  target
# 231    NaN       0
# 373    NaN       0
# 480    NaN       0
# 496    NaN       0
# 529    NaN       0
# 596    NaN       0
# 835    NaN       0
# 855    NaN       0
# 941    NaN       0
# 956    NaN       0
# 1095   NaN       0
# 1176   NaN       0
# 1248   NaN       0
# 1418   NaN       0
# 1469   NaN       0
# 1529   NaN       0
# 1631   NaN       0
# 1757   NaN       0
# 1944   NaN       0
# 1959   NaN       0
# 1971   NaN       0
# 2160   NaN       0
# 2216   NaN       0
# 2220   NaN       0
# 2221   NaN       0
# 2282   NaN       0
# 2376   NaN       0
# 2429   NaN       0
# 2432   NaN       0
# 2616   NaN       0
# ...    ...     ...
# 47681  NaN       2
# 48814  NaN       2
# 48838  NaN       2
# 49587  NaN       2
# 50395  NaN       2
# 50753  NaN       2
# 50820  NaN       2
# 51160  NaN       2
# 51313  NaN       2
# 51530  NaN       2
# 51604  NaN       2
# 51736  NaN       2
# 51933  NaN       2
# 53335  NaN       2
# 54172  NaN       2
# ...

# %%
my_df.dropna(inplace=True)
my_df.reset_index(drop=True,inplace=True)
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63328 entries, 0 to 63327
# Data columns (total 2 columns):
# text      63328 non-null object
# target    63328 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 989.6+ KB

# %%
from nltk import word_tokenize
import nltk
# nltk.download('punkt')
tokens = [word_tokenize(sen) for sen in my_df.text]

# %%
def lower_token(tokens): 
    return [w.lower() for w in tokens]    
    
lower_tokens = [lower_token(token) for token in tokens]

# %%
from nltk.corpus import stopwords
stoplist = stopwords.words('english')
def removeStopWords(tokens): 
    return [word for word in tokens if word not in stoplist]
filtered_words = [removeStopWords(sen) for sen in lower_tokens]
my_df['Text_Final'] = [' '.join(sen) for sen in filtered_words]
my_df['tokens'] = filtered_words

# %%
happy = []
sad = []
fear = []
for l in my_df.target:
    if(l == 0):
        happy.append(1)
        sad.append(0)
        fear.append(0)
    elif(l == 1):
        happy.append(0)
        sad.append(1)
        fear.append(0)
    elif(l == 2):
        happy.append(0)
        sad.append(0)
        fear.append(1)

# %%
my_df['happy']= happy
my_df['sad']= sad
my_df['fear']= fear

# %%
my_df
# Out:
#                                                     text  target  \
# 0      i want to play ludo king with you please insta...       0
# 1      awesome haha long may it continue we are watch...       0
# 2                           awesome thank you great list       0
# 3      awesome how he touched people by not only his ...       0
# 4      how sweet alexxis birthday message to happy bi...       0
# 5      sorry to bother you and it was brilliant and w...       0
# 6                                       you look awesome       0
# 7      just saw in an awesome panel at the festivalof...       0
# 8                                  wray s fbi is awesome       0
# 9      nolacak kanka d n p taga destek vermen de yete...       0
# 10       sno looks awesome what armor set is she wearing       0
# 11     this is such an awesome video what a wonderful...       0
# 12                                  this is awesome dude       0
# ...

# %%
# my_df.to_csv('processed_data.csv', )
# my_df = pd.read_csv('processed_data.csv')

# %%
# df = pd.DataFrame()
# df['tokens'] = my_df['tokens']
# df['target'] = my_df['target']
# df.head()

# %%
data_train, data_test = train_test_split(my_df, test_size=0.2, random_state=50)

# %%
data_train.shape
data_test.shape
# Out:
# (12666, 7)

# %%
y_train = data_train['target']
y_test = data_test['target']
print(set(y_train))
print(set(y_test))
# Out:
# {0, 1, 2}
# {0, 1, 2}

# %%
y_train = y_train.astype(str) 
y_test = y_test.astype(str) 
# type(y_train[0])
# type(y_test[0])

# %%
label_names = ['happy', 'sad', 'fear']

# %%
y_train = data_train[label_names].values
y_test = data_test[label_names].values

# %%
x_train = train_cnn_data
x_test = test_cnn_data

# %%
all_training_words = [word for tokens in data_train["tokens"] for word in tokens]
training_sentence_lengths = [len(tokens) for tokens in data_train["tokens"]]
TRAINING_VOCAB = sorted(list(set(all_training_words)))
print("%s words total, with a vocabulary size of %s" % (len(all_training_words), len(TRAINING_VOCAB)))
print("Max sentence length is %s" % max(training_sentence_lengths))
# Out:
# 384979 words total, with a vocabulary size of 38357
# Max sentence length is 24

# %%
all_test_words = [word for tokens in data_test["tokens"] for word in tokens]
test_sentence_lengths = [len(tokens) for tokens in data_test["tokens"]]
TEST_VOCAB = sorted(list(set(all_test_words)))
print("%s words total, with a vocabulary size of %s" % (len(all_test_words), len(TEST_VOCAB)))
print("Max sentence length is %s" % max(test_sentence_lengths))
# Out:
# 96546 words total, with a vocabulary size of 17201
# Max sentence length is 21

# %%
tokenizer = Tokenizer()
tokenizer = Tokenizer(num_words=len(TRAINING_VOCAB), lower=True, char_level=False)
tokenizer.fit_on_texts(data_train["Text_Final"].tolist())
training_sequences = tokenizer.texts_to_sequences(data_train["Text_Final"].tolist())

train_word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(train_word_index))
# Out:
# Found 38357 unique tokens.

# %%
vocab_size = len(train_word_index)

# %%
MAX_SEQUENCE_LENGTH = 24
EMBEDDING_DIM = 300

# %%
train_cnn_data = pad_sequences(training_sequences, maxlen=MAX_SEQUENCE_LENGTH)

# %%
# train_embedding_weights = np.zeros((len(train_word_index)+1, EMBEDDING_DIM))
# for word,index in train_word_index.items():
#     train_embedding_weights[index,:] = word2vec[word] if word in word2vec else np.random.rand(EMBEDDING_DIM)
# print(train_embedding_weights.shape)

# %%
test_sequences = tokenizer.texts_to_sequences(data_test["Text_Final"].tolist())
test_cnn_data = pad_sequences(test_sequences, maxlen=MAX_SEQUENCE_LENGTH)

# %%
train_cnn_data.shape
# Out:
# (50662, 24)

# %%
test_cnn_data.shape
# Out:
# (12666, 24)

# %%
# define model
model = Sequential()
model.add(Embedding(vocab_size, 100, input_length=MAX_SEQUENCE_LENGTH))
model.add(Conv1D(filters=32, kernel_size=8, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dense(3, activation='sigmoid'))
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_9 (Embedding)      (None, 24, 100)           3835700
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 17, 32)            25632
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 8, 32)             0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                2570
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 33
# ...
# Total params: 3,863,935
# Trainable params: 3,863,935
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# compile network
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(x_train, y_train, epochs=10, verbose=1, batch_size = 64)
# Out:
# Epoch 1/10
# 50662/50662 [==============================] - 90s 2ms/step - loss: 0.1238 - acc: 0.9552
# Epoch 2/10
# 50662/50662 [==============================] - 88s 2ms/step - loss: 0.0728 - acc: 0.9731
# Epoch 3/10
# 50662/50662 [==============================] - 90s 2ms/step - loss: 0.0533 - acc: 0.9800
# Epoch 4/10
# 50662/50662 [==============================] - 92s 2ms/step - loss: 0.0461 - acc: 0.9820
# Epoch 5/10
# 50662/50662 [==============================] - 92s 2ms/step - loss: 0.0413 - acc: 0.9833
# Epoch 6/10
# 50662/50662 [==============================] - 90s 2ms/step - loss: 0.0393 - acc: 0.9837
# Epoch 7/10
# 50662/50662 [==============================] - 92s 2ms/step - loss: 0.0383 - acc: 0.9841
# Epoch 8/10
# 50662/50662 [==============================] - 93s 2ms/step - loss: 0.0368 - acc: 0.9847
# Epoch 9/10
# 50662/50662 [==============================] - 89s 2ms/step - loss: 0.0358 - acc: 0.9849
# Epoch 10/10
# ...

# %%
predictions = model.predict(x_test, batch_size=1024, verbose=1)
# Out:
# 12666/12666 [==============================] - 1s 83us/step

# %%
labels = [0, 1, 2]
prediction_labels=[]
for p in predictions:
    prediction_labels.append(labels[np.argmax(p)])

# %%
accuracy = sum(data_test.target==prediction_labels)/len(prediction_labels)
print('Test Accuracy : ', accuracy)
# Out:
# Test Accuracy :  0.8135954523922312

# %%
data_test.target.value_counts()
# Out:
# 0    4266
# 1    4263
# 2    4137
# Name: target, dtype: int64

# %%
# evaluate
loss, acc = model.evaluate(x_test, y_test, verbose=1)
print('Test Accuracy: %f' % (acc*100))
# Out:
# 12666/12666 [==============================] - 1s 105us/step
# Test Accuracy: 81.359545

# %% [markdown]
# # word2vec

# %%
# !pip3 install gensim
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/b3/8b/b31d8c6d74292f745aa06fdc02fb8e1e529736ab1de922e5402a50e0a042/gensim-3.8.3-cp36-cp36m-win_amd64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/ca/5d/7344d00b55f060243cf4f04c2fcee8c245a0af2b0bc236fc6dbb5021dcd6/Cython-0.29.14-cp36-cp36m-win_amd64.whl
# ...
#   Found existing installation: cython 0.29.10
#     Uninstalling cython-0.29.10:
#       Successfully uninstalled cython-0.29.10
#   Rolling back uninstall of cython
#   Moving to c:\users\anaya\appdata\roaming\python\python36\scripts\cygdb.exe
#    from C:\Users\Anaya\AppData\Local\Temp\pip-uninstall-hi4nk6qo\cygdb.exe
#   Moving to c:\users\anaya\appdata\roaming\python\python36\scripts\cython.exe
#    from C:\Users\Anaya\AppData\Local\Temp\pip-uninstall-hi4nk6qo\cython.exe
#   Moving to c:\users\anaya\appdata\roaming\python\python36\scripts\cythonize.exe
#    from C:\Users\Anaya\AppData\Local\Temp\pip-uninstall-hi4nk6qo\cythonize.exe
# ...

# %%
from gensim.models import KeyedVectors
model_ug_cbow = KeyedVectors.load('w2v_model_ug_cbow.word2vec')
model_ug_sg = KeyedVectors.load('w2v_model_ug_sg.word2vec')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-99-73ceb30d78ba> in <module>()
# ----> 1 from gensim.models import KeyedVectors
#       2 model_ug_cbow = KeyedVectors.load('w2v_model_ug_cbow.word2vec')
#       3 model_ug_sg = KeyedVectors.load('w2v_model_ug_sg.word2vec')
#
# ModuleNotFoundError: No module named 'gensim'
